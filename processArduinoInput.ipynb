# %% [markdown]
# # Initialization

# %%
# import block
import ipywidgets
import ipynb.fs.defs.source.localFunctions as localFunctions # ignore the squiggle, this is fine

# %%
##### RUN ME, SELECT PORT FROM DROPDOWN THAT APPEARS #####

# get ports
currentFunctionalPorts = localFunctions.portInspector()

# make the widget
portDropdown = ipywidgets.Dropdown(
    options = currentFunctionalPorts,
    description = 'Serial Port:',
    disabled = False,
)

display(portDropdown)

# %%
# variable definitions, adust if needed
numSensors = 10
sensorsList = list(range(2, numSensors + 1))
PORT = portDropdown.value
BAUD = 9600

# directory locations
csvDump = f"./outputCSVs"
dataDump = f"./data"

# %% [markdown]
# # Data Processing

# %%
# running one test; start me for each test, different file names will be saved (ordered by time stamp)
### oneTrialRunner(expectedPort,rateBAUD, expectedSensors, directoryForOutput)

# %%
# running in follow mode for lots of tests; will initialize new file for each test
### multiTrialRunner(expectedPort, rateBAUD, expectedSensors, directoryForOutput, maxTrials = None)

# %%
# run to combine files and drop output in data

# %% [markdown]
# # Data Visualization
